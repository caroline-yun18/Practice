# %%
print("hello world")
# Out:
# hello world

# %%
import yfinance as yf

# %%
import yfinance as yf
import datetime
import pandas as pd

# %%
import yahoofinancials

# %%
ticker = "MSFT"
yahoo_financials = YahooFinancials(ticker)
data = yahoo_financials.get_historical_price_data("2018-04-24","2020-04-24","daily")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-255273505b34> in <module>
#       1 ticker = "MSFT"
# ----> 2 yahoo_financials = YahooFinancials(ticker)
#       3 data = yahoo_financials.get_historical_price_data("2018-04-24","2020-04-24","daily")
#
# NameError: name 'YahooFinancials' is not defined

# %%
object = datetime.datetime.now()
print(object)
# Out:
# 2021-10-31 14:34:04.856488

# %%
stocks = ['AMZN',"MSFT","INTC","GOOG","INFY.NS"]
start = datetime.datetime.today() - datetime.timedelta(30)
end = datetime.datetime.today()
cl_price = pd.DataFrame()
ohlcv_data = {} #storing in key value pairs, with the ticker and
#then the data frame

# %%
print(start)
print(end)
# Out:
# 2021-10-01 14:32:30.701317
# 2021-10-31 14:32:30.701389

# %%
for ticker in stocks:
    #for the column ticker in cl_price, assinging it the adjusted
    #close value
    cl_price[ticker] = yf.download(ticker,start,end)['Adj Close']
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
for ticker in stocks:
    ohlcv_data[ticker] = yf.download(ticker,start,end)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
ohlcv_data
# Out:
# {'AMZN':                    Open         High          Low        Close    Adj Close  \
#  Date
#  2021-10-01  3289.010010  3309.169922  3255.939941  3283.260010  3283.260010
#  2021-10-04  3279.389893  3279.989990  3176.250000  3189.780029  3189.780029
#  2021-10-05  3204.500000  3260.729980  3202.459961  3221.000000  3221.000000
#  2021-10-06  3213.530029  3264.340088  3198.620117  3262.010010  3262.010010
#  2021-10-07  3291.540039  3325.750000  3283.060059  3302.429932  3302.429932
#  2021-10-08  3317.000000  3321.429932  3288.199951  3288.620117  3288.620117
#  2021-10-11  3275.000000  3292.590088  3238.100098  3246.300049  3246.300049
#  2021-10-12  3257.000000  3267.530029  3236.280029  3247.330078  3247.330078
#  2021-10-13  3269.709961  3288.379883  3261.090088  3284.280029  3284.280029
#  2021-10-14  3302.449951  3312.600098  3290.780029  3299.860107  3299.860107
#  2021-10-15  3311.419922  3410.419922  3304.000000  3409.020020  3409.020020
# ...

# %%
ohlcv_data["MSFT"]["Open"]
# Out:
# Date
# 2021-10-01    282.119995
# 2021-10-04    287.399994
# 2021-10-05    284.049988
# 2021-10-06    285.779999
# 2021-10-07    295.179993
# 2021-10-08    296.220001
# 2021-10-11    292.920013
# 2021-10-12    295.339996
# 2021-10-13    294.910004
# 2021-10-14    299.209991
# 2021-10-15    302.339996
# 2021-10-18    303.570007
# 2021-10-19    308.350006
# 2021-10-20    309.209991
# 2021-10-21    307.170013
# 2021-10-22    310.399994
# 2021-10-25    309.359985
# 2021-10-26    311.000000
# 2021-10-27    316.000000
# 2021-10-28    324.329987
# 2021-10-29    324.130005
# Name: Open, dtype: float64

# %%
import YahooFinancials
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-42-8ba2d097b400> in <module>
# ----> 1 import YahooFinancials
#
# ModuleNotFoundError: No module named 'YahooFinancials'

# %%
ticker = "MSFT"
yahoo_financials = YahooFinancials(ticker)
data = yahoo_financials.get_historical_price_data("2018-04-24","2020-04-24","daily")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-255273505b34> in <module>
#       1 ticker = "MSFT"
# ----> 2 yahoo_financials = YahooFinancials(ticker)
#       3 data = yahoo_financials.get_historical_price_data("2018-04-24","2020-04-24","daily")
#
# NameError: name 'YahooFinancials' is not defined
